# %% [markdown]
# Pandas - это мощная библиотека для анализа данных в Python, которая предоставляет удобные структуры данных и функции для работы с табличными данными. Она построена на основе NumPy и широко используется в области анализа данных, науки о данных и машинного обучения.

# %% [markdown]
# Установка
# Чтобы установить Pandas, используйте pip:
# ```
# pip install pandas
# ```

# %% [markdown]
# Импорт библиотеки:
# ```python
# import pandas as pd
# ```

# %%
import pandas as pd

# %% [markdown]
# ## Основные структуры данных

# %% [markdown]
# Pandas предлагает две основные структуры данных:

# %% [markdown]
# #### **Series**: одномерный массив, который может содержать данные любого типа (целые числа, строки, числа с плавающей запятой и т. д.). Каждое значение в Series имеет индекс.

# %%
# Создание Series
l = [1, 2, 3, 4, 5]
s = pd.Series(l)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# #### **DataFrame**: двумерная таблица, состоящая из строк и столбцов. Каждый столбец может содержать данные разных типов. DataFrame можно рассматривать как контейнер для нескольких Series.

# %%
# Создание DataFrame
data = {
    'Имя': [['Аня', 'Катя'], 'Борис', 'Вика'],
    'Возраст': [25, 30, 22],
    'Группа': [1, 2, 3]
}

df = pd.DataFrame(data)
df
# Out:
#            Имя  Возраст  Группа
# 0  [Аня, Катя]       25       1
# 1        Борис       30       2
# 2         Вика       22       3

# %%
dict1 = {
    'BKONE': ['Ася', 'Александра','Анна', 'Айдана'],
    'BKIMB': ['Полина', 'Эдуард', 'Егор', 'Екатерина']
}
pd.DataFrame(dict1)
# Out:
#         BKONE      BKIMB
# 0         Ася     Полина
# 1  Александра     Эдуард
# 2        Анна       Егор
# 3      Айдана  Екатерина

# %% [markdown]
# ##  Основные операции с данными

# %% [markdown]
# #### Чтение и запись данных
#
# Pandas поддерживает множество форматов для чтения и записи данных, включая CSV, Excel, SQL и другие.

# %%
# Пример
# Чтение данных из CSV файла
df = pd.read_csv('data.csv')

# Запись данных в CSV файл
df.to_csv('output.csv', index=False)

# %%
df = pd.read_csv('Данные.csv')

# %%
df
# Out:
#       Пол        Рост         Вес      Зарплата  Количество детей  \
# 0       0  164.649896   70.571989  64862.219990                11
# 1       1  161.848675   71.057826  84363.937072                 9
# 2       0  177.369475  121.403749  51815.021424                 6
# 3       0  172.092985  109.637526  41394.612395                13
# 4       0  179.429473  124.594123  58207.982122                 9
# ...   ...         ...         ...           ...               ...
# 1495    0  176.381210   58.407913  59425.245343                 6
# 1496    1  156.109572   81.983951  62588.842882                13
# 1497    1  167.008691   90.967677  85758.327915                 6
# 1498    0  179.310398   87.353057  54489.484706                12
# 1499    0  183.427191  105.698570  70187.765383                13
#
#                 Город     Образование    Профессия Группа крови  Возраст
# 0        Екатеринбург         Среднее     Менеджер            O       60
# ...

# %% [markdown]
# #### Чтение

# %% [markdown]
# CSV (Comma-Separated Values)

# %%
# Чтение CSV-файла
df = pd.read_csv('data.csv')

# Указать кодировку, если есть проблемы
df = pd.read_csv('data.csv', encoding='utf-8')

# Указать разделитель (если не запятая)
df = pd.read_csv('data.txt', sep='\t')  # для TSV

# %% [markdown]
#  Excel

# %%
# Чтение Excel-файла
df = pd.read_excel('data.xlsx', sheet_name='Sheet1')

# Можно указать несколько листов или индекс
df = pd.read_excel('data.xlsx', sheet_name=0)  # первый лист

# %% [markdown]
# JSON

# %%
# Чтение JSON-файла
df = pd.read_json('data.json')

# Или из строки JSON
import json
json_str = '{"name": ["Alice", "Bob"], "age": [25, 30]}'
df = pd.read_json(json_str)

# %% [markdown]
# #### Запись

# %% [markdown]
# CSV

# %%
# Запись в CSV
df.to_csv('output.csv', index=False)  # index=False — без колонки индекса

# %% [markdown]
# Excel

# %%
# Запись в Excel
df.to_excel('output.xlsx', sheet_name='Data', index=False)

# %% [markdown]
# Основные методы
# * head(): показывает первые n строк DataFrame.
# * tail(): показывает последние n строк DataFrame.
# * info(): выводит информацию о DataFrame, включая типы данных и количество ненулевых значений.
# * describe(): предоставляет статистику по числовым столбцам

# %% [markdown]
# #### Индексация и фильтрация данных

# %% [markdown]
# Индексация
#
# * **loc** для доступа по меткам.
# * **iloc** для доступа по позициям.

# %%
# Индексация по меткам
print(df.loc[0])

# Индексация по позициям
print(df.iloc[0])

# %%
df['Количество детей'].argmax()
# Out:
# np.int64(795)

# %%
df[
    (df['Рост'] >= 170)&(df['Город'] == 'Москва')&(df['Профессия'] == 'Менеджер')&(df['Возраст'] <= 30)&(df['Возраст'] >= 20)
    ]
# Out:
#       Пол        Рост        Вес      Зарплата  Количество детей   Город  \
# 21      0  177.641103  85.120000  86821.631221                10  Москва
# 213     0  176.453814  83.233148  83012.367181                10  Москва
# 217     0  182.372070  84.402185  75299.920339                10  Москва
# 287     0  172.286089  66.105431  78366.762184                21  Москва
# 615     0  177.238474  40.378446  87641.657817                17  Москва
# 758     0  170.706181  47.473997  69948.916727                15  Москва
# 797     0  173.534734  93.077507  77036.485885                18  Москва
# 800     0  170.760691  86.335526  73381.752146                 9  Москва
# 1218    0  172.766622  90.137280  76326.644532                11  Москва
#
#          Образование Профессия Группа крови  Возраст
# 21           Среднее  Менеджер            O       26
# 213   Послевузовское  Менеджер            O       27
# 217          Среднее  Менеджер            B       30
# ...

# %%
df[df['Профессия'] == 'Менеджер']
# Out:
#       Пол        Рост         Вес      Зарплата  Количество детей  \
# 0       0  164.649896   70.571989  64862.219990                11
# 1       1  161.848675   71.057826  84363.937072                 9
# 4       0  179.429473  124.594123  58207.982122                 9
# 7       0  176.737544   77.131002  77081.389332                 5
# 11      0  169.007413   74.239208  62418.719551                11
# ...   ...         ...         ...           ...               ...
# 1474    1  167.426970   91.420784  55165.116536                 5
# 1478    1  169.483801   96.223581  51083.445487                 8
# 1484    0  177.733254   81.941704  66391.404737                 9
# 1488    0  157.928280   86.835531  72111.623987                14
# 1493    1  174.183886   76.661194  66548.618834                10
#
#                 Город     Образование Профессия Группа крови  Возраст
# 0        Екатеринбург         Среднее  Менеджер            O       60
# ...

# %%
df[['Рост', 'Вес', 'Количество детей']].corr()
# Out:
#                       Рост       Вес  Количество детей
# Рост              1.000000  0.206961          0.006415
# Вес               0.206961  1.000000          0.023761
# Количество детей  0.006415  0.023761          1.000000

# %% [markdown]
# #### Фильтрация
# Вы можете фильтровать данные с помощью логических условий.

# %%
# Фильтрация по условию
young_people = df[df['Возраст'] < 30]
print(young_people)

# %% [markdown]
# #### Обработка отсутствующих данных

# %% [markdown]
# Pandas предоставляет функции для обработки отсутствующих данных.
#
# * **isnull()**: проверяет, есть ли пропущенные значения.
# * **dropna()**: удаляет строки с пропущенными значениями.
# * **fillna()**: заполняет пропущенные значения.

# %%
# Проверка на пропущенные значения
print(df.isnull().sum())

# Удаление строк с пропущенными значениями
df_cleaned = df.dropna()

# Заполнение пропущенных значений
df_filled = df.fillna(0)

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# #### Визуализация данных

# %% [markdown]
# Pandas интегрируется с библиотеками визуализации, такими как Matplotlib и Seaborn.

# %%
from matplotlib import pyplot as plt
# Построение графика
df['Возраст'].hist()
plt.title('Распределение возраста')
plt.xlabel('Возраст')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# #### Группировка данных:

# %%
data = {
    'Имя': ['Аня', 'Аня', 'Борис', 'Вика'],
    'Возраст': [34, 25, 30, 22],
    'Группа': [1, 4, 2, 3]
}

df = pd.DataFrame(data)
df
# Out:
#      Имя  Возраст  Группа
# 0    Аня       34       1
# 1    Аня       25       4
# 2  Борис       30       2
# 3   Вика       22       3

# %%
grouped = df.groupby('Имя').mean()  # Средние значения по Именам
grouped
# Out:
#        Возраст  Группа
# Имя
# Аня       29.5     2.5
# Борис     30.0     2.0
# Вика      22.0     3.0

# %%
df
# Out:
#       Пол        Рост         Вес      Зарплата  Количество детей  \
# 0       0  164.649896   70.571989  64862.219990                11
# 1       1  161.848675   71.057826  84363.937072                 9
# 2       0  177.369475  121.403749  51815.021424                 6
# 3       0  172.092985  109.637526  41394.612395                13
# 4       0  179.429473  124.594123  58207.982122                 9
# ...   ...         ...         ...           ...               ...
# 1495    0  176.381210   58.407913  59425.245343                 6
# 1496    1  156.109572   81.983951  62588.842882                13
# 1497    1  167.008691   90.967677  85758.327915                 6
# 1498    0  179.310398   87.353057  54489.484706                12
# 1499    0  183.427191  105.698570  70187.765383                13
#
#                 Город     Образование    Профессия Группа крови  Возраст
# 0        Екатеринбург         Среднее     Менеджер            O       60
# ...

# %%
df.groupby('Город')[['Зарплата','Вес','Рост']].mean()
# Out:
#                      Зарплата        Вес        Рост
# Город
# Екатеринбург     60087.936553  84.100841  169.935383
# Казань           54910.021728  83.812150  169.850103
# Москва           79748.599331  84.657388  170.880502
# Новосибирск      50419.526334  84.506276  170.635175
# Санкт-Петербург  70330.040690  84.052463  169.752830

# %%
df['Зарплата + премия'] = df['Зарплата'] + 0.5*df['Зарплата']
df
# Out:
#       Пол        Рост         Вес      Зарплата  Количество детей  \
# 0       0  164.649896   70.571989  64862.219990                11
# 1       1  161.848675   71.057826  84363.937072                 9
# 2       0  177.369475  121.403749  51815.021424                 6
# 3       0  172.092985  109.637526  41394.612395                13
# 4       0  179.429473  124.594123  58207.982122                 9
# ...   ...         ...         ...           ...               ...
# 1495    0  176.381210   58.407913  59425.245343                 6
# 1496    1  156.109572   81.983951  62588.842882                13
# 1497    1  167.008691   90.967677  85758.327915                 6
# 1498    0  179.310398   87.353057  54489.484706                12
# 1499    0  183.427191  105.698570  70187.765383                13
#
#                 Город     Образование    Профессия Группа крови  Возраст  \
# 0        Екатеринбург         Среднее     Менеджер            O       60
# ...

# %%
df.drop(columns=['Зарплата + премия'], inplace=True)
df
# Out:
#       Пол        Рост         Вес      Зарплата  Количество детей  \
# 0       0  164.649896   70.571989  64862.219990                11
# 1       1  161.848675   71.057826  84363.937072                 9
# 2       0  177.369475  121.403749  51815.021424                 6
# 3       0  172.092985  109.637526  41394.612395                13
# 4       0  179.429473  124.594123  58207.982122                 9
# ...   ...         ...         ...           ...               ...
# 1495    0  176.381210   58.407913  59425.245343                 6
# 1496    1  156.109572   81.983951  62588.842882                13
# 1497    1  167.008691   90.967677  85758.327915                 6
# 1498    0  179.310398   87.353057  54489.484706                12
# 1499    0  183.427191  105.698570  70187.765383                13
#
#                 Город     Образование    Профессия Группа крови  Возраст
# 0        Екатеринбург         Среднее     Менеджер            O       60
# ...

# %% [markdown]
# #### Добавление и удаление столбцов:

# %%
# Добавления
df['Рост'] = [170, 160, 165, 190]
df
# Out:
#      Имя  Возраст  Группа  Рост
# 0    Аня       34       1   170
# 1    Аня       25       4   160
# 2  Борис       30       2   165
# 3   Вика       22       3   190

# %%
# Удаление столбца
df.drop('Рост', axis=1, inplace=True)
df
# Out:
#      Имя  Возраст  Группа
# 0    Аня       34       1
# 1    Аня       25       4
# 2  Борис       30       2
# 3   Вика       22       3

# %% [markdown]
# #### Слияние и объединение:

# %%
df1 = pd.DataFrame({'key': ['A', 'B', 'C'], 'value1': [1, 2, 3]})
df1
# Out:
#   key  value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2 = pd.DataFrame({'key': ['A', 'B', 'D'], 'value2': [4, 5, 6]})
df2
# Out:
#   key  value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
df1 = pd.merge(df1,df2, on='key',how='outer')

# %%
merged = pd.merge(df1, df2, on='key', how='outer')  # Объединение по ключу
merged
# Out:
#   key  value1  value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
df1.fillna(df1[['value1', 'value2']].mean())
# Out:
#   key  value1  value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     5.0
# 3   D     2.0     6.0

# %%
import numpy as np
lamda = 5
np.random.poisson(lamda)
# Out:
# 7

# %%
means = []
count_means = 1000

for i in range(count_means):
  x = []
  for j in range(1000):
    x.append(np.random.poisson(lamda))
  means.append(sum(x)/len(x))

plt.hist(means)
# Out:
# (array([  2.,  18.,  56., 125., 203., 254., 181.,  99.,  52.,  10.]),
#  array([4.766 , 4.8091, 4.8522, 4.8953, 4.9384, 4.9815, 5.0246, 5.0677,
#         5.1108, 5.1539, 5.197 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.random.poisson(lamda,size=100000000).reshape(10000, 10000).mean(axis=1) , bins=50);

# %%
plt.hist(means)
plt.hist(x, alpha=0.2)
# Out:
# (array([ 87., 107., 103.,  98., 103.,  96., 105., 105.,  99.,  97.]),
#  array([-9.98520112, -7.99211166, -5.99902221, -4.00593275, -2.01284329,
#         -0.01975384,  1.97333562,  3.96642508,  5.95951453,  7.95260399,
#          9.94569345]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.animation as animation

fig, ax = plt.subplots()
#ax.set_xlim([-10, 10])

scat = ax.scatter(1, 0)
x = np.linspace(-10, 10, 10)


def animate(i):
    scat.set_offsets((x[i], np.sin(x[i])))
    return (scat,)


ani = animation.FuncAnimation(fig, animate, repeat=True, frames=len(x) - 1, interval=50)

# To save the animation using Pillow as a gif
writer = animation.PillowWriter(fps=15,
                                metadata=dict(artist='Me'),
                                bitrate=1800)
ani.save('scatter.gif', writer=writer)

plt.show()

# %%
df
# Out:
#       Пол        Рост         Вес      Зарплата  Количество детей  \
# 0       0  164.649896   70.571989  64862.219990                11
# 1       1  161.848675   71.057826  84363.937072                 9
# 2       0  177.369475  121.403749  51815.021424                 6
# 3       0  172.092985  109.637526  41394.612395                13
# 4       0  179.429473  124.594123  58207.982122                 9
# ...   ...         ...         ...           ...               ...
# 1495    0  176.381210   58.407913  59425.245343                 6
# 1496    1  156.109572   81.983951  62588.842882                13
# 1497    1  167.008691   90.967677  85758.327915                 6
# 1498    0  179.310398   87.353057  54489.484706                12
# 1499    0  183.427191  105.698570  70187.765383                13
#
#                 Город     Образование    Профессия Группа крови  Возраст
# 0        Екатеринбург         Среднее     Менеджер            O       60
# ...

# %% [markdown]
# $ f(x) = x^5 + 2x^4 + x + 1 → min$

# %%
x = np.linspace(-10,10)
y = x**5 + 2*x**4 + x + 1
x[np.argmin(y)]
plt.plot(x, y)
plt.scatter(x[np.argmin(y)],np.min(y))

# %%
# y = x^5 + 2x^4 + x + 1
# y' = 5x^4 + 8x^3 + 1
# y' =0
# 5x^4 + 8x^3 + 1 = 0
#
