# %% [markdown]
# Matplotlib — это одна из самых популярных библиотек для визуализации данных в Python. Она позволяет создавать статические, анимационные и интерактивные графики. В этой лекции мы рассмотрим основные аспекты работы с Matplotlib, включая установку, базовые команды и создание различных типов графиков.

# %% [markdown]
# Установка Matplotlib
# Если у вас еще не установлен Matplotlib, его можно установить с помощью pip:
# ```
# pip install matplotlib
# ```

# %% [markdown]
# Импорт библиотеки:
# ```python
# from matplotlib import pyplot as plt
# ```

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Графики

# %% [markdown]
# **В функциях указаны не все аргументы, их необходимо читать в документации**

# %% [markdown]
# ### **Создание графика plot:**
# ```python
# plt.plot(x, y, color='red', linewidth=1, markersize=1, marker='p')
# ```
# * color - цвет графика
# * linewidth - толщина линии
# * markersize - размер маркера
# * marker - тип маркера https://matplotlib.org/stable/api/markers_api.html
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
x = np.linspace(-1, 1, 100)
y = np.exp(x)
plt.plot(x, y, color='red', linewidth=1, markersize=1, marker='p');

# %% [markdown]
# ### **Создание графика scatter:**
# ```python
# plt.scatter(x, y, color='red', linewidth=0.01, marker='*')
# ```
# * color - цвет графика
# * linewidth - толщина линии
# * marker - тип маркера https://matplotlib.org/stable/api/markers_api.html
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
plt.scatter(x, y, color='red', linewidth=0.01, marker='*')

# %% [markdown]
# ### **Создание гистограммы:**
#
# ```python
# plt.hist(x, bins=100, color='red')
# ```
# * color - цвет графика
# * bins - количество ячеек одинаковой ширины в диапазоне
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# %%
normal = np.random.normal(0,1, size=1000)
plt.hist(normal, bins=100, color='pink');

# %% [markdown]
# ###  **Создание ящика с усами:**
#
# ```python
# plt.boxplot(x, color='red')
# ```
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
plt.boxplot(normal);

# %% [markdown]
# ### **Создание круговой диаграммы:**
# ```python
# plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['pink', 'purple', 'violet'])
# ```
#
#
# * labels - метки для каждого сегмента
# * autopct - маркировка сегмента числовым значением
# * colors - цвета
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html

# %%
labels = 'БКОНЕ', 'КиМБ231', 'КиМБ232'
sizes = [30, 20, 25]
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['pink', 'purple', 'violet']);

# %% [markdown]
# ### **Столбчатая диаграмма**
# ```python
# plt.bar(x, y2, color='orange')
# ```

# %%
labels = 'БКОНЕ', 'КиМБ231', 'КиМБ232'
sizes = [30, 20, 25]
plt.bar(labels, sizes, color='orange')
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### **Полярные координаты**
# ```python
# plt.polar(theta, r); - аналогично plot
# ```
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.polar.html

# %%
theta = np.linspace(0, 2*np.pi, 1000)
r = np.sin(6*theta)
plt.polar(theta, r);

# %% [markdown]
# ### **3D график**

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.cos(np.sqrt(X**2 + Y**2))

surf = ax.plot_surface(X, Y, Z, cmap='plasma')

# %% [markdown]
# ### **Изображение**
# ```
# plt.imshow(matrix)
# ```

# %%
matrix = np.random.normal(0, 1, size=(100, 100, 3))
plt.imshow(matrix, cmap='gray');
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### **Облако слов**

# %%
from wordcloud import WordCloud

# %%
#cpode
text = """
Мой дядя самых честных правил,
Когда не в шутку занемог,
Он уважать себя заставил
И лучше выдумать не мог.
Его пример другим наука;
Но, боже мой, какая скука
С больным сидеть и день и ночь,
Не отходя ни шагу прочь!
Какое низкое коварство
Полуживого забавлять,
Ему подушки поправлять,
Печально подносить лекарство,
Вздыхать и думать про себя:
Когда же черт возьмет тебя
"""
gen = WordCloud(width=800, height=400, background_color='white', colormap='icefire', max_words=100).generate(text)
plt.imshow(gen)
plt.axis('off');

# %% [markdown]
# ### **Heatmap Seaborn**

# %%
import seaborn as sns
uniform_data = np.random.rand(10, 12)

# %%
sns.heatmap(np.corrcoef(uniform_data), cmap='icefire', linewidths=0.1)
plt.title('Матрица')
# Out:
# Text(0.5, 1.0, 'Матрица')

# %% [markdown]
# ### **Настройка и кастомизация графиков**

# %% [markdown]
# #### Подпись холста
#
# ```python
# plt.title("Заголовок графика", fontsize=14)
# ```
# * fontsize - размер шрифта
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.title.html

# %%
plt.title("Заголовок графика", fontsize=14);

# %% [markdown]
# #### Легенда
#
# ```python
# plt.legend(loc='best', fontsize=10) # loc='best' - по умолчанию
# ```
# * loc -задает расположение легенды (например, 'upper left', 'upper right', 'lower left', 'lower right').
# * fontsize - размер шрифта

# %%
plt.plot(x, y, label='Линия 1')
plt.legend(loc='upper left', fontsize=10)

# %% [markdown]
# #### Настройка осей

# %% [markdown]
# ##### Подписи осей
#
# ```python
# plt.xlabel("Ось X", fontsize=12, rotation=45)
# plt.ylabel("Ось Y", fontsize=12, rotation=0);
# ```
# * fontsize - размер шрифта
# * rotation - поворот подписи

# %%
plt.xlabel("Ось X", fontsize=12, rotation=45)
plt.ylabel("Ось Y", fontsize=12);

# %% [markdown]
# ##### Установка диапазона осей
#
# Вы можете установить диапазон для осей X и Y с помощью plt.xlim() и plt.ylim()
#
# ```python
# plt.xlim(0, 6)
# plt.ylim(0, 12)
# ```

# %%
plt.xlim(0, 6)
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %% [markdown]
# ##### Настройка меток осей
# Вы можете настроить метки осей с помощью plt.xticks() и plt.yticks():
# ```
# plt.xticks([1, 2, 3, 4, 5], labels=['A', 'B', 'C', 'D', 'E'], rotation=45)
# plt.yticks([2, 4, 6, 8, 10, 12], labels=['2', '4', '6', '8', '10', '12'])
# ```
# * labels - метки
# * rotation - поворот подписей
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html

# %%
plt.xticks([0, 2, 3, 4, 5], labels=['A', 'B', 'C', 'D', 'E'], rotation=45)
plt.yticks([2, 4, 6, 8, 10, 12], labels=['2', '4', '6', '8', '10', '12']);

# %% [markdown]
# ##### Отключение осей
#
# ```python
# ptl.axis('off')
# ```

# %% [markdown]
# #### Заполнение области между двумя линиями
#
# ```python
# plt.fill_between(x,y);
# ```
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.fill_between.html#matplotlib.axes.Axes.fill_between

# %%
plt.fill_between(x,y);

# %% [markdown]
# #### Добавление текста
#
# ```python
# plt.text(x, y, text, fontsize=14)
# ```

# %%
plt.text(1, 1, 'Привет', fontsize=14)
plt.xlim(-1, 2)
plt.ylim(-1, 2)
# Out:
# (-1.0, 2.0)

# %% [markdown]
# #### Стили
#
# ```
# plt.style.use('grayscale')
# ```

# %% [markdown]
# Вот некоторые из них
# 1. seaborn: стиль, который улучшает визуализацию и делает графики более привлекательными.
# 2. ggplot: стиль, вдохновленный графической системой ggplot2 в R.
# 3. bmh: стиль с более мягкими цветами и четкими линиями.
# 4. dark_background: стиль с темным фоном, который хорошо подходит для презентаций.
# 5. fivethirtyeight: стиль, вдохновленный графиками сайта FiveThirtyEight.

# %%
print(plt.style.available) # Список доступных стилей
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# #### Цвет фона
# plt.figure().patch.set_facecolor('purple')

# %%
plt.figure().patch.set_facecolor('purple')
plt.text(1, 1, 'Привет', fontsize=14)
plt.xlim(-1, 2)
plt.ylim(-1, 2)
# Out:
# (-1.0, 2.0)

# %% [markdown]
# ### **Несколько графиков на одном холсте**

# %% [markdown]
# ##### **subplot()**
#
# Функция subplot() позволяет вам размещать несколько графиков в одной фигуре, задавая количество строк и столбцов в сетке.
#
# ```
# plt.subplot(nrows, ncols, index)
# ```
# * nrows: количество строк в сетке.
# * ncols: количество столбцов в сетке.
# * index: индекс текущего графика (начиная с 1).

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]
y2 = [1, 4, 6, 8, 10]

plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)  # 2 строки, 1 столбец, 1-й график
plt.plot(x, y1, color='blue', marker='o')
plt.title("Линейный график")
plt.xlabel("X")
plt.ylabel("Y1")

# Второй график
plt.subplot(2, 1, 2)  # 2 строки, 1 столбец, 2-й график
plt.bar(x, y2, color='orange')
plt.title("Столбчатая диаграмма")
plt.xlabel("X")
plt.ylabel("Y2")

# Показать графики
plt.tight_layout()  # Автоматически подгоняет графики для лучшего отображения
plt.show()

# %% [markdown]
# ##### **subplots()**
#
# Функция subplots() предоставляет более удобный способ создания нескольких графиков, возвращая как объект фигуры, так и массив осей.
# ```
# fig, axs = plt.subplots(nrows, ncols)
# ```
# * fig: объект фигуры.
# * axs: массив осей.

# %%
import matplotlib.pyplot as plt

# Данные для графиков
x = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]
y2 = [1, 4, 6, 8, 10]

# Создание фигуры и осей
fig, axs = plt.subplots(2, 1, figsize=(10, 6))

# Первый график
axs[0].plot(x, y1, color='blue', marker='o')
axs[0].set_title("Линейный график")
axs[0].set_xlabel("X")
axs[0].set_ylabel("Y1")

# Второй график
axs[1].bar(x, y2, color='orange')
axs[1].set_title("Столбчатая диаграмма")
axs[1].set_xlabel("X")
axs[1].set_ylabel("Y2")

# Показать графики
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Настройка расположения графиков

# %% [markdown]
# Вы можете настроить расположение графиков, изменяя количество строк и столбцов, а также размеры отдельных графиков. Например, вы можете создать сетку 2x2 и оставить один график пустым:

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Первый график
axs[0, 0].plot(x, y1, color='blue', marker='o')
axs[0, 0].set_title("Линейный график")

# Второй график
axs[0, 1].bar(x, y2, color='orange')
axs[0, 1].set_title("Столбчатая диаграмма")

# Третий график - пустой
axs[1, 0].axis('off')  # Отключаем оси

# Четвертый график
axs[1, 1].scatter(x, y1, color='green')
axs[1, 1].set_title("Скаттер-график")

plt.tight_layout()
plt.show()
